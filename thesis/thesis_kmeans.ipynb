# %%
#@title Install dependencies { display-mode: "form" }
# !pip install biopython
# !pip install pyperclip
# !pip install umap-learn[plot]
# !pip install holoviews

# sys.path.append('/usr/local/lib/python3.9/site-packages/') #append site-packages to path to run conda/mmseqs2/cd-hit

# !wget https://repo.anaconda.com/miniconda/Miniconda3-py39_23.3.1-0-Linux-x86_64.sh
# !chmod +x Miniconda3-py39_23.3.1-0-Linux-x86_64.sh
# !bash ./Miniconda3-py39_23.3.1-0-Linux-x86_64.sh -b -f -p /usr/local
# install via conda
# !conda install -c conda-forge -c bioconda mmseqs2

# %%
#@title Mount drive and load libraries { display-mode: "form" }
import os
from google.colab import drive

drive.mount('/content/drive/')
path = '/content/drive/MyDrive/msc_project'
os.chdir(path)

import pandas as pd
import sys, numpy as np
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib.pyplot as plt
import umap
from mpl_toolkits.mplot3d import Axes3D  # Import 3D plotting functionality
from useful_functions import fasta_to_df, df_to_fasta, add_counts
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#@title Generate fasta file for clustering
df = pd.read_csv('all_paired/230716_human_paired_seqs.csv', low_memory=False)
df = df.iloc[:, 2:]
df.head()
tensors = pd.read_csv('all_paired/230716_scfv_10000.csv')
names = tensors['seq'].to_list()

df = df[df['seq_id'].isin(names)]

def df_to_fasta(df: pd, cols: list, f: str):
    x = cols[0]
    y = cols[1]
    with open(f, 'w') as out:
        for i in range(df.shape[0]):
            out.write('>' + df[x].iloc[i] + '\n' + df[y].iloc[i] + '\n')

df_to_fasta(df=df, cols=['seq_id', 'scfv'], f='230716_scfv_10000.fasta')

# %%
#@title Cluster sequences
os.chdir('/tmp')
# !mkdir /tmp/new_tmp
# !cp /content/drive/MyDrive/msc_project/all_paired/230716_scfv_10000.fasta /tmp

# !sudo mmseqs easy-cluster 230716_scfv_10000.fasta clusterRes new_tmp --min-seq-id 0.8 -c 0.8 --cov-mode 1

# !mv /tmp/clusterRes_all_seqs.fasta /content/drive/MyDrive/msc_project/all_paired
# !mv /tmp/clusterRes_cluster.tsv /content/drive/MyDrive/msc_project/all_paired
# !mv /tmp/clusterRes_rep_seq.fasta /content/drive/MyDrive/msc_project/all_paired

os.chdir('/content/drive/MyDrive/msc_project/all_paired')
# Out:
# mkdir: cannot create directory ‘/tmp/new_tmp’: File exists
# easy-cluster 230716_scfv_10000.fasta clusterRes new_tmp --min-seq-id 0.8 -c 0.8 --cov-mode 1
#
# MMseqs Version:                     	13.45111
# Substitution matrix                 	nucl:nucleotide.out,aa:blosum62.out
# Seed substitution matrix            	nucl:nucleotide.out,aa:VTML80.out
# Sensitivity                         	4
# k-mer length                        	0
# k-score                             	2147483647
# Alphabet size                       	nucl:5,aa:21
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.8
# Coverage mode                       	1
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	1
# Pseudo count b                      	1.5
# Spaced k-mer pattern
# Local temporary path
# Threads                             	4
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.8
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Gap open cost                       	nucl:5,aa:11
# Gap extension cost                  	nucl:2,aa:1
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	true
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	nucl:0.200,aa:0.000
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
# Database type                       	0
# Shuffle input database              	true
# Createdb mode                       	1
# Write lookup file                   	0
# Offset of numeric ids               	0
#
# createdb 230716_scfv_10000.fasta new_tmp/797415778928849408/input --dbtype 0 --shuffle 1 --createdb-mode 1 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Shuffle database cannot be combined with --createdb-mode 0
# We recompute with --shuffle 0
# Converting sequences
# [9899] 0s 7ms
# Time for merging to input_h: 0h 0m 0s 0ms
# Time for merging to input: 0h 0m 0s 0ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 7ms
# Create directory new_tmp/797415778928849408/clu_tmp
# cluster new_tmp/797415778928849408/input new_tmp/797415778928849408/clu new_tmp/797415778928849408/clu_tmp --max-seqs 20 -c 0.8 --cov-mode 1 --spaced-kmer-mode 1 --alignment-mode 3 -e 0.001 --min-seq-id 0.8 --remove-tmp-files 1
#
# Set cluster sensitivity to -s 1.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 1
# linclust new_tmp/797415778928849408/input new_tmp/797415778928849408/clu_tmp/6427837364140297979/clu_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 4 --compressed 0 -v 3 --sub-mat nucl:nucleotide.out,aa:blosum62.out -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.8 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca 1 --pcb 1.5 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --gap-open nucl:5,aa:11 --gap-extend nucl:2,aa:1 --zdrop 40 --alph-size nucl:5,aa:13 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale nucl:0.200,aa:0.000 --adjust-kmer-len 0 --mask 0 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 1 --force-reuse 0
#
# kmermatcher new_tmp/797415778928849408/input new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref --sub-mat nucl:nucleotide.out,aa:blosum62.out --alph-size nucl:5,aa:13 --min-seq-id 0.8 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale nucl:0.200,aa:0.000 --adjust-kmer-len 0 --mask 0 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 4 --compressed 0 -v 3
#
# kmermatcher new_tmp/797415778928849408/input new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref --sub-mat nucl:nucleotide.out,aa:blosum62.out --alph-size nucl:5,aa:13 --min-seq-id 0.8 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale nucl:0.200,aa:0.000 --adjust-kmer-len 0 --mask 0 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 4 --compressed 0 -v 3
#
# Database size: 9955 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 100.00% 9.95K 0s 94ms
# Sort kmer 0h 0m 0s 19ms
# Sort by rep. sequence 0h 0m 0s 11ms
# Time for fill: 0h 0m 0s 6ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 244ms
# rescorediagonal new_tmp/797415778928849408/input new_tmp/797415778928849408/input new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_rescore1 --sub-mat nucl:nucleotide.out,aa:blosum62.out --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.8 -a 0 --cov-mode 1 --min-seq-id 0.8 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 4 --compressed 0 -v 3
#
# [=================================================================] 100.00% 9.95K 0s 106ms
# Time for merging to pref_rescore1: 0h 0m 0s 110ms
# Time for processing: 0h 0m 0s 250ms
# clust new_tmp/797415778928849408/input new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_rescore1 new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 4 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 3ms
#
# Size of the sequence database: 9955
# Size of the alignment database: 9955
# Number of clusters: 7563
#
# Writing results 0h 0m 0s 2ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 71ms
# createsubdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/order_redundancy new_tmp/797415778928849408/input new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 5ms
# createsubdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/order_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 73ms
# filterdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_filter1 new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_filter2 --filter-file new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/order_redundancy --threads 4 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 100.00% 7.56K 0s 45ms
# Time for merging to pref_filter2: 0h 0m 0s 2ms
# Time for processing: 0h 0m 0s 315ms
# rescorediagonal new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/input_step_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/input_step_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_filter2 new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_rescore2 --sub-mat nucl:nucleotide.out,aa:blosum62.out --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.8 -a 0 --cov-mode 1 --min-seq-id 0.8 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 4 --compressed 0 -v 3
#
# [=================================================================] 100.00% 7.56K 0s 41ms
# Time for merging to pref_rescore2: 0h 0m 0s 3ms
# Time for processing: 0h 0m 0s 112ms
# align new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/input_step_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/input_step_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_rescore2 new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/aln --sub-mat nucl:nucleotide.out,aa:blosum62.out -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.8 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca 1 --pcb 1.5 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --gap-open nucl:5,aa:11 --gap-extend nucl:2,aa:1 --zdrop 40 --threads 4 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 7563 type: Aminoacid
# Target database size: 7563 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 7.56K 6s 343ms
# Time for merging to aln: 0h 0m 0s 2ms
# 59642 alignments calculated
# 11917 sequence pairs passed the thresholds (0.199809 of overall calculated)
# 1.575697 hits per query sequence
# Time for processing: 0h 0m 6s 591ms
# clust new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/input_step_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/aln new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 4 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 2ms
#
# Size of the sequence database: 7563
# Size of the alignment database: 7563
# Number of clusters: 4390
#
# Writing results 0h 0m 0s 0ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 10ms
# mergeclusters new_tmp/797415778928849408/input new_tmp/797415778928849408/clu_tmp/6427837364140297979/clu_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pre_clust new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/clust --threads 4 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 100.00% 7.56K 0s 18ms
# Clustering step 2
# [=================================================================] 100.00% 4.39K 0s 114ms
# Write merged clustering
# [=================================================================] 100.00% 9.95K 0s 217ms
# Time for merging to clu_redundancy: 0h 0m 0s 2ms
# Time for processing: 0h 0m 0s 223ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_filter1 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_rescore1 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pre_clust -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_filter2 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/pref_rescore2 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/aln -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/linclust/9538491903918845927/clust -v 3
#
# Time for processing: 0h 0m 0s 0ms
# createsubdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/clu_redundancy new_tmp/797415778928849408/input new_tmp/797415778928849408/clu_tmp/6427837364140297979/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 2ms
# prefilter new_tmp/797415778928849408/clu_tmp/6427837364140297979/input_step_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/input_step_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/pref_step0 --sub-mat nucl:nucleotide.out,aa:blosum62.out --seed-sub-mat nucl:nucleotide.out,aa:VTML80.out -s 1 -k 0 --k-score 2147483647 --alph-size nucl:5,aa:21 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.8 --cov-mode 1 --comp-bias-corr 0 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca 1 --pcb 1.5 --threads 4 --compressed 0 -v 3
#
# Query database size: 4390 type: Aminoacid
# Estimated memory consumption: 986M
# Target database size: 4390 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 100.00% 4.39K 0s 109ms
# Index table: Masked residues: 3127
# Index table: fill
# [=================================================================] 100.00% 4.39K 0s 56ms
# Index statistics
# Entries:          493004
# DB size:          491 MB
# Avg k-mer size:   0.007703
# Top 10 k-mers
#     YNYTSS	4389
#     YYKSGT	4389
#     STTYYY	4388
#     LRETYY	1587
#     FDWQLV	1425
#     PGAKIY	1417
#     QAGGWV	1311
#     TGPRGS	1237
#     RLCAFT	1138
#     PGARIY	1131
# Time for index table init: 0h 0m 0s 953ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 4390
# Target db start 1 to 4390
# [=================================================================] 100.00% 4.39K 1s 367ms
#
# 2.700403 k-mers per position
# 66396 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 20 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 1ms
# Time for processing: 0h 0m 3s 830ms
# align new_tmp/797415778928849408/clu_tmp/6427837364140297979/input_step_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/input_step_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/pref_step0 new_tmp/797415778928849408/clu_tmp/6427837364140297979/aln_step0 --sub-mat nucl:nucleotide.out,aa:blosum62.out -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.8 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca 1 --pcb 1.5 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --gap-open nucl:5,aa:11 --gap-extend nucl:2,aa:1 --zdrop 40 --threads 4 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 4390 type: Aminoacid
# Target database size: 4390 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 4.39K 9s 278ms
# Time for merging to aln_step0: 0h 0m 0s 3ms
# 87800 alignments calculated
# 70445 sequence pairs passed the thresholds (0.802335 of overall calculated)
# 16.046698 hits per query sequence
# Time for processing: 0h 0m 9s 305ms
# clust new_tmp/797415778928849408/clu_tmp/6427837364140297979/input_step_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/aln_step0 new_tmp/797415778928849408/clu_tmp/6427837364140297979/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 4 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 169ms
#
# Size of the sequence database: 4390
# Size of the alignment database: 4390
# Number of clusters: 1820
#
# Writing results 0h 0m 0s 0ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 383ms
# mergeclusters new_tmp/797415778928849408/input new_tmp/797415778928849408/clu new_tmp/797415778928849408/clu_tmp/6427837364140297979/clu_redundancy new_tmp/797415778928849408/clu_tmp/6427837364140297979/clu_step0 --threads 4 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 100.00% 4.39K 0s 48ms
# Clustering step 2
# [=================================================================] 100.00% 1.82K 0s 149ms
# Write merged clustering
# [=================================================================] 100.00% 9.95K 0s 256ms
# Time for merging to clu: 0h 0m 0s 1ms
# Time for processing: 0h 0m 0s 463ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/clu_redundancy -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/pref_step0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/aln_step0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_tmp/6427837364140297979/clu_step0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# createtsv new_tmp/797415778928849408/input new_tmp/797415778928849408/input new_tmp/797415778928849408/clu new_tmp/797415778928849408/cluster.tsv --threads 4 -v 3
#
# Time for merging to cluster.tsv: 0h 0m 0s 2ms
# Time for processing: 0h 0m 0s 155ms
# result2repseq new_tmp/797415778928849408/input new_tmp/797415778928849408/clu new_tmp/797415778928849408/clu_rep --db-load-mode 0 --compressed 0 --threads 4 -v 3
#
# [=================================================================] 100.00% 1.82K 0s 29ms
# Time for merging to clu_rep: 0h 0m 0s 2ms
# Time for processing: 0h 0m 0s 140ms
# result2flat new_tmp/797415778928849408/input new_tmp/797415778928849408/input new_tmp/797415778928849408/clu_rep new_tmp/797415778928849408/rep_seq.fasta --use-fasta-header -v 3
#
# Time for processing: 0h 0m 0s 5ms
# createseqfiledb new_tmp/797415778928849408/input new_tmp/797415778928849408/clu new_tmp/797415778928849408/clu_seqs --threads 4 -v 3
#
# [=================================================================] 100.00% 1.82K 0s 25ms
# Time for merging to clu_seqs: 0h 0m 0s 1ms
# Time for processing: 0h 0m 0s 193ms
# result2flat new_tmp/797415778928849408/input new_tmp/797415778928849408/input new_tmp/797415778928849408/clu_seqs new_tmp/797415778928849408/all_seqs.fasta -v 3
#
# Time for processing: 0h 0m 0s 16ms
# rmdb new_tmp/797415778928849408/input -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/input_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_seqs -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu_rep -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb new_tmp/797415778928849408/clu -v 3
#
# Time for processing: 0h 0m 0s 0ms

# %%
#@title Generate clusters from ID pairings
clus = pd.read_csv('clusterRes_cluster.tsv', sep='\t', header=None)

# Create a dictionary to store the cluster numbers
cluster_dict = {}

# Iterate over the rows of the dataframe
for idx, row in clus.iterrows():
    id1 = row[0]
    id2 = row[1]

    # Check if id1 or id2 already have a cluster assigned
    if id1 in cluster_dict and id2 not in cluster_dict:
        cluster_dict[id2] = cluster_dict[id1]
    elif id1 not in cluster_dict and id2 in cluster_dict:
        cluster_dict[id1] = cluster_dict[id2]
    elif id1 not in cluster_dict and id2 not in cluster_dict:
        # Assign a new cluster number
        new_cluster = len(cluster_dict)
        cluster_dict[id1] = new_cluster
        cluster_dict[id2] = new_cluster

# Assign cluster numbers to the original dataframe
clus['cluster'] = clus[0].map(cluster_dict)

# Create a single column of unique IDs with respective cluster numbers
l = clus['cluster'].to_list() + clus['cluster'].to_list()
new = pd.concat([clus[0], clus[1]])
new = pd.DataFrame(new)
new['cluster'] = l

new.drop_duplicates(subset=0, inplace=True)
new.rename(columns={0:'seq'}, inplace=True)

test = new.merge(right=tensors, how='left', on='seq')
test.drop(columns=['Unnamed: 0'], inplace=True)

num_clus = len(set(test['cluster']))

print(f'{num_clus} clusters in this set')
test.head()
# Out:
# 1820 clusters in this set
#                                                  seq  cluster         0  \
# 0  GTCAAGTCACTGTCGG-1_contig_1_GTCAAGTCACTGTCGG-1...        0  0.018020
# 1  GTGCGGTCAAAGTGCG-1_contig_2_GTGCGGTCAAAGTGCG-1...        1  0.015495
# 2  TACACGATCTTCAACT-1_contig_2_TACACGATCTTCAACT-1...       17  0.005905
# 3  TACTTACCATCACAAC-1_contig_2_TACTTACCATCACAAC-1...       19 -0.003359
# 4  TAGGCATCAGTCCTTC-1_contig_2_TAGGCATCAGTCCTTC-1...       20  0.010260
#
#          1        2         3        4        5         6        7  ...  \
# 0  0.08887  0.01721  0.004787 -0.02261  0.03925 -0.029250 -0.08070  ...
# 1  0.09740  0.02005 -0.008680 -0.03345  0.02898 -0.007168 -0.07880  ...
# 2  0.09920  0.01680 -0.003012 -0.01474  0.02577 -0.013560 -0.09860  ...
# 3  0.10920  0.02408  0.000740 -0.01773  0.03726 -0.020980 -0.08840  ...
# 4  0.10266  0.02391  0.002360 -0.01804  0.04443 -0.020360 -0.08704  ...
#
#       1014     1015     1016     1017      1018      1019     1020     1021  \
# 0 -0.07690  0.03980 -0.06630 -0.08170 -0.011060 -0.001887  0.04450  0.04416
# 1 -0.08356  0.00972 -0.06775 -0.07196 -0.042000 -0.013530  0.03550  0.05917
# 2 -0.08840  0.01445 -0.06177 -0.07850 -0.015144 -0.015870  0.01157  0.05975
# 3 -0.09820  0.02623 -0.05954 -0.07200 -0.012650 -0.001715  0.00554  0.04020
# 4 -0.09094  0.02162 -0.06520 -0.07110 -0.009450 -0.007336  0.02809  0.04114
#
#        1022      1023
# 0  0.016660 -0.007225
# 1  0.013040  0.005714
# 2  0.002142 -0.010560
# 3  0.003582 -0.017960
# 4 -0.002392 -0.009550
#
# [5 rows x 1026 columns]

# %%
tsne = TSNE(n_components=2, random_state=42)

test = test.dropna()
protein_tsne = tsne.fit_transform(test.iloc[:,2:])

X=protein_tsne[:, 0]
y=protein_tsne[:, 1]
metadata = test['cluster']  # Convert to string type

new_df = pd.DataFrame({'X': X, 'y': y, 'metadata': metadata})

# Set scatter plot parameters for smaller points
scatter_kws = {'s': 10}  # Adjust the 's' value to control point size

if num_clus < 20:
  boolie = True
else:
  boolie = False

# Use the 'hue' argument to provide a factor variable
sns.lmplot(x='X', y='y', data=new_df, hue='metadata', fit_reg=False, legend=boolie, scatter_kws=scatter_kws)

plt.show()

# %%
tsne = TSNE(n_components=3, random_state=42)  # Set n_components to 3

protein_tsne = tsne.fit_transform(test.iloc[:, 2:])

X = protein_tsne[:, 0]
y = protein_tsne[:, 1]
z = protein_tsne[:, 2]  # New component 'z'
metadata = test['cluster']

new_df = pd.DataFrame({'X': X, 'y': y, 'z': z, 'metadata': metadata})

# # Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Use the 'hue' argument to provide a factor variable
ax.scatter(new_df['X'], new_df['y'], new_df['z'], c=new_df['metadata'])

plt.show()

# %% [markdown]
# Running into issues with UMAP. For some reason the conda forge and pip don't result in a functioning import.
#
# Fix next time and also implement kmeans and see whether it does anything useful. Use metrics such as cluster purity to see whether kmeans can pick clusters that overlap with mmseqs2. Are there any other ways you can generate 'labels' for how similar antibodies are? Maybe concatenating the light and heavy chain V segments?

# %%
umap_embedding = umap.UMAP(n_components=2, random_state=42)
protein_umap = umap_embedding.fit_transform(test.iloc[:, 2:])
X = protein_umap[:, 0]
y = protein_umap[:, 1]
metadata = test['cluster']

new_df = pd.DataFrame({'X': X, 'y': y, 'metadata':metadata})

# Set scatter plot parameters for smaller points
scatter_kws = {'s': 10}  # Adjust the 's' value to control point size

if num_clus < 20:
  boolie = True
else:
  boolie = False

# Use the 'hue' argument to provide a factor variable
sns.lmplot(x='X', y='y', data=new_df, hue='metadata', fit_reg=False, legend=boolie, scatter_kws=scatter_kws)

#plt.scatter(new_df['X'], new_df['y'])

plt.show()

# %%
# import numpy as np
# import umap
# import holoviews as hv

# # Generate a random dataset
# data = np.random.rand(100, 3)

# # Create a UMAP object
# reducer = umap.UMAP(n_neighbors=10, min_dist=0.1)

# # Fit and transform the data
# embedding = reducer.fit_transform(data)
hv.extension('matplotlib')
# Visualize the embedding
hv.Points(embedding).opts(color='k', marker='+', s=50)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
