# %%
#@title Mount drive and load libraries
import os
from google.colab import drive

drive.mount('/content/drive/')
path = '/content/drive/MyDrive/msc_project'
os.chdir(path)
# Out:
# Mounted at /content/drive/

# %%
# !git config --global user.name 'marwin-bramble'
# !git config --global user.email 'mattrbalmforth@hotmail.com'
# !git config --global user.password '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'

# %%
token = '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'
username = 'marwin-bramble'
repo = 'msc_project'

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'msc_project'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# !cd {repo}
# !ls
# Out:
# [Errno 2] No such file or directory: 'msc_project'
# /content/drive/MyDrive/msc_project/msc_project
# README.md

# %%
# !mv /content/drive/MyDrive/Colab_notebooks/thesis /content/drive/MyDrive/msc_project/msc_project

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	thesis/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add --all

# %%
# !git commit -a -m "added useful functions to msc_project"
# Out:
# [main 59c76ea] added useful functions to msc_project
#  1 file changed, 316 insertions(+)
#  create mode 100644 useful_functions.py

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/marwin-bramble/msc_project (fetch)
# origin	https://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@github.com/marwin-bramble/msc_project (push)

# %%
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 3.83 KiB | 435.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/marwin-bramble/msc_project
#    c899b65..59c76ea  main -> main

# %%
# Out:
# error: invalid key: remote.origin.default_branch
